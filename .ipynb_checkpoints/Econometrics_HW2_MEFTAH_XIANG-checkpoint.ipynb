# %%
library(forecast)

# %% [markdown]
# # Load data

# %%
cpi <- read.csv('Inflation_France_OECD.csv',sep=';')

# %%
head(cpi)
# Out:
#   Time   CPI
# 1 Jan-00 1.5
# 2 Feb-00 1.4
# 3 Mar-00 1.5
# 4 Apr-00 1.2
# 5 May-00 1.4
# 6 Jun-00 1.7

# %% [markdown]
# #### Question 1

# %% [markdown]
# Transform to time series

# %%
cpi_ts <- ts(cpi$CPI,start = c(2000,1),frequency = 12)

# %% [markdown]
# Standard statistics for CPI

# %%
summary(cpi_ts)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -0.700   0.900   1.600   1.441   2.000   3.600

# %% [markdown]
# Plot of the entire time series

# %%
plot(cpi_ts)
# Out:
# plot without title

# %% [markdown]
# ACF

# %%
acf(cpi_ts)
# Out:
# Plot with title “Series  cpi_ts”

# %% [markdown]
# PACF

# %%
pacf(cpi_ts)
# Out:
# Plot with title “Series  cpi_ts”

# %% [markdown]
# CPI seems to have a global decreasing trend. The ACF plot has the characteristics of an AR process, and it is confirmed by the partial ACF.

# %% [markdown]
# #### Question 2

# %% [markdown]
# Split data into training and testing sets

# %%
train <- ts(cpi_ts[1:103],start = c(2000,1),frequency = 12)

# %%
test <- cpi_ts[104:206]

# %% [markdown]
# Model with an AR(1)

# %%
model <- arima(train,order = c(1,0,0))

# %%
model
# Out:
# Call:
# arima(x = train, order = c(1, 0, 0))
#
# Coefficients:
#          ar1  intercept
#       0.8897     1.9851
# s.e.  0.0516     0.2289
#
# sigma^2 estimated as 0.07369:  log likelihood = -12.63,  aic = 31.25

# %% [markdown]
# #### Question 3

# %%
# Store estimated parameters 
slope = c()
intercept = c()
fcast = c()

for (i in c(0:103))
{
    # set train data 
    tr <- ts(cpi_ts[1:(103+i)],start = c(2000,1),frequency = 12)
    # train model 
    ar1 <- arima(tr,order=c(1,0,0))
    # record slope, intercept, horizon 1 to 6 forecasts
    slope = c(slope,as.numeric(ar1$coef[1]))
    intercept = c(intercept,as.numeric(ar1$coef[2]))
    fcast = rbind(fcast,as.data.frame(forecast(ar1,h=6))[,1])
}

# %% [markdown]
# Break in slope parameter

# %%
plot(slope,type='l')
# Out:
# plot without title

# %% [markdown]
# Remark : There is a break when using a few additional points to the 50 % first observations. And then, the slope is increasing slowly until all the data are used as training data.

# %% [markdown]
# Break for intercept parameter

# %%
plot(intercept, type='l')
# Out:
# plot without title

# %% [markdown]
#  Remark : There is also a break when using a few additional points to the 50 % first observations. And then, the intercept is decreasing slowly until all the data are used as training data.

# %% [markdown]
# #### Question 4

# %% [markdown]
# Set true values for horizon 1 to horizon 6

# %%
true_val = c()
for (i in c(1:98))
{

    true_val = rbind(true_val,cpi_ts[(103+i):(108+i)])
}

# %% [markdown]
# Compute MFE

# %%
MFE_ar = apply(true_val-fcast[1:98,],2,mean)
MFE_ar = as.data.frame(MFE_ar)
rownames(MFE_ar) <- c('Horizon1','Horizon2','Horizon3','Horizon4','Horizon5','Horizon6')

# %%
MFE_ar
# Out:
#          MFE_ar
# Horizon1 -0.07137255
# Horizon2 -0.13601743
# Horizon3 -0.19515782
# Horizon4 -0.24795790
# Horizon5 -0.28030031
# Horizon6 -0.30560418

# %% [markdown]
# Compute RMFE

# %%
RMFE_ar = apply((true_val-fcast[1:98,])**2,2,mean)
RMFE_ar = sqrt(as.data.frame(RMFE_ar))
rownames(RMFE_ar) <- c('Horizon1','Horizon2','Horizon3','Horizon4','Horizon5','Horizon6')

# %%
RMFE_ar
# Out:
#          RMFE_ar
# Horizon1 0.2562672
# Horizon2 0.4025833
# Horizon3 0.5342321
# Horizon4 0.6461818
# Horizon5 0.7348898
# Horizon6 0.7998810

# %% [markdown]
# So, we can see that as the horizon increases, the forecast error increases too.

# %% [markdown]
# #### Question 5

# %% [markdown]
# We do the naive forecasting with the average of the last 12 observations

# %%
# Store estimated parameters 
fcast_naive = data.frame()

naive_forecast = function(data){return(mean(data[(length(data)-12):length(data)]))}

for (i in c(0:103))
{
    # set train data 
    tr <- ts(cpi_ts[1:(103+i)],start = c(2000,1),frequency = 12)
    
    naive = c()
    horizon = c()
    for(h in 1:6){ 
        naive = naive_forecast(c(tr,naive))
        horizon = c(horizon, naive)
    }
    fcast_naive = rbind(fcast_naive, as.data.frame(horizon)[, 1])
}
colnames(fcast_naive) = c("Horizon1", "Horizon2","Horizon3","Horizon4", "Horizon5","Horizon6")

# %%
MFE_naive = data.frame(MFE_naive = apply(true_val-fcast_naive[1:98,],2,mean))
MFE_naive
# Out:
#          MFE_naive
# Horizon1 -0.2043956
# Horizon2 -0.2234935
# Horizon3 -0.2482750
# Horizon4 -0.2696475
# Horizon5 -0.2727044
# Horizon6 -0.2706633

# %%
RMFE_naive = data.frame(RMFE_naive = sqrt(apply((true_val-fcast_naive[1:98,])**2,2,mean)))
RMFE_naive
# Out:
#          RMFE_naive
# Horizon1 0.8251555
# Horizon2 0.8833163
# Horizon3 0.9574229
# Horizon4 1.0235308
# Horizon5 1.0821176
# Horizon6 1.1251042

# %% [markdown]
# #### Question 5

# %%
# Store estimated parameters 
fcast_random = data.frame()

random_forecast = function(data){return(data[length(data)])}

for (i in c(0:103))
{
    # set train data 
    tr <- ts(cpi_ts[1:(103+i)],start = c(2000,1),frequency = 12)
    
    random = c()
    horizon = c()
    for(h in 1:6){ 
        random = random_forecast(c(tr,random))
        horizon = c(horizon, random)
    }
    fcast_random = rbind(fcast_random, as.data.frame(horizon)[, 1])
}
colnames(fcast_random) = c("Horizon1", "Horizon2","Horizon3","Horizon4", "Horizon5","Horizon6")

# %%
MFE_random = data.frame(MFE_random = apply(true_val-fcast_random[1:98,],2,mean))
MFE_random
# Out:
#          MFE_random
# Horizon1 -0.03265306
# Horizon2 -0.06122449
# Horizon3 -0.08673469
# Horizon4 -0.10816327
# Horizon5 -0.11122449
# Horizon6 -0.10918367

# %%
RMFE_random = data.frame(RMFE_random = sqrt(apply((true_val-fcast_random[1:98,])**2,2,mean)))
RMFE_random
# Out:
#          RMFE_random
# Horizon1 0.2519313
# Horizon2 0.3976975
# Horizon3 0.5374733
# Horizon4 0.6625554
# Horizon5 0.7652531
# Horizon6 0.8466621

# %% [markdown]
# #### Question 7

# %%
err = cbind(MFE_ar, MFE_naive,MFE_random,"|||||"=rep("|||||",6), RMFE_ar, RMFE_naive, RMFE_random)
err
# Out:
#          MFE_ar      MFE_naive  MFE_random  ||||| RMFE_ar   RMFE_naive
# Horizon1 -0.07137255 -0.2043956 -0.03265306 ||||| 0.2562672 0.8251555
# Horizon2 -0.13601743 -0.2234935 -0.06122449 ||||| 0.4025833 0.8833163
# Horizon3 -0.19515782 -0.2482750 -0.08673469 ||||| 0.5342321 0.9574229
# Horizon4 -0.24795790 -0.2696475 -0.10816327 ||||| 0.6461818 1.0235308
# Horizon5 -0.28030031 -0.2727044 -0.11122449 ||||| 0.7348898 1.0821176
# Horizon6 -0.30560418 -0.2706633 -0.10918367 ||||| 0.7998810 1.1251042
#          RMFE_random
# Horizon1 0.2519313
# Horizon2 0.3976975
# Horizon3 0.5374733
# Horizon4 0.6625554
# Horizon5 0.7652531
# Horizon6 0.8466621

# %% [markdown]
# Clearly the naive model is not a good option given the relatively small time horizons we take into account here. Indeed the model is then sensitive to the outlier during the previous year and shift the prediction way far form the true value. The no-memory process (random walk) performs the best for small horizons (below than 2 or 3); because being conservative for short horizons is a wise decision given the relative "regularity" between two or three consecutive months. The relative small MFE also highlights this. The AR process is the one that is the most generalizable in the long run.

# %% [markdown]
# #### Question 8

# %%
Forecast_Error_AR = as.data.frame((true_val-fcast[1:98]))
colnames(Forecast_Error_AR) = c("Horizon1", "Horizon2","Horizon3","Horizon4", "Horizon5","Horizon6")
plot.ts(Forecast_Error_AR)
# Out:
# plot without title

# %%
Forecast_Error_Naive = as.data.frame((true_val-fcast_naive[1:98,]))
colnames(Forecast_Error_Naive) = c("Horizon1", "Horizon2","Horizon3","Horizon4", "Horizon5","Horizon6")
plot.ts(Forecast_Error_Naive)
# Out:
# plot without title

# %%
Forecast_Error_Random = as.data.frame((true_val-fcast_random[1:98,]))
colnames(Forecast_Error_Random) = c("Horizon1", "Horizon2","Horizon3","Horizon4", "Horizon5","Horizon6")
plot.ts(Forecast_Error_Random)
# Out:
# plot without title

# %% [markdown]
# It confirms what we said earlier, the forecast error for the AR process and the random walk seem to be roughly gaussian noise of mean 0 with finite variance (for horizon1, except for the first prediction windows). It can be then concluded that these models can reasonably be relevant for prediction. What we can notice from question 3, is that the AR(1) coefficient is relatively close to 1 (random walk) so all the observations and conclusions we made are relevant. Here again the naive model (Moving Average of period p = 12 months) is not relevant.
